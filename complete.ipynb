# %%
# Audio Generator 

# python .\kokoro_heart.py
# Out:
# ^C
# Total sentences: 11 | Synth chunks: 3
# PyTorch CUDA available: False
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# [1/3] Cat is a careful jumper. Before every leap, they crouch, wiggle their hips, and ...
# [2/3] If the surface doesn’t look safe, they’ll change direction instead of risking a ...
# [3/3] Giving your cat stable spots to climb helps them stay confident and safe. So tha...
# Done. Wrote 'heart_all.wav' (30.68s).
# c:\Users\Thariq\Documents\ITS\PROJECT\PCC\.venv\lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(
# c:\Users\Thariq\Documents\ITS\PROJECT\PCC\.venv\lib\site-packages\torch\nn\utils\weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)

# %%
# # Soft-sub Generator 
stable-ts heart_all.wav --output heart_all.srt --output_format srt --device cuda --language en --word_timestamps True --max_chars 42 --max_words 8
# stable-ts heart_all.wav --output x.srt --output_format srt --device cuda --language en --word_timestamps True --max_chars 42 --max_words 8

(Get-Content .\heart_all.srt) -replace '#00ff00','#ff00ffff' |  Set-Content .\heart_all.srt -Encoding utf8
# Out:
# ^C

# %%
# Video Generator
# python -u build_video_from_footage_ml.p y --footage_dir footage --input_txt footage_example.txt --audio_wav heart_all.wav --out_video heart_all_visual.mp4 --debug
python footage.py --footage_dir footage --input_txt input.txt --subs_srt heart_all.srt --audio_wav heart_all.wav --out_video heart_all_visual.mp4 --debug

# Hard-sub Generator
python burn_hardsub_fit_ass.py --keep_font_color --ass_color_order rgb  --margin_v_ratio 0.24  --base_scale 0.056
# Out:
# [+] Audio duration: 29.32s
# [+] Labels loaded: 5
# [debug] counters summary: files=24 unseen=17 min=0 median=0 max=2
# [debug] counters file: footage\.selection_counters.json
# [debug] scraped keywords: fall, fight, jump, m, meow, purr, run, sleep
# [debug] embedding 9 names with 'all-MiniLM-L6-v2'...
# [+] Clips: 5 | per-clip ~ 5.87s (min=5.87, max=5.87)
#
# [progress] [01/5] |####--------------------| label: jump
# [debug] class match: jump  | pool=11
#         - 'jump': candidates=11 min_count=0 max_count=0
#         pool preview: jump_1.mp4:0, jump_10_m.mp4:0, jump_11_m.mp4:0, jump_2_m.mp4:0, jump_3.mp4:0, jump_4.mp4:0, jump_5_m.mp4:0, jump_6.mp4:0, jump_7_m.mp4:0, jump_8_m.mp4:0, jump_9_m.mp4:0
# [pick] by class  → jump_9_m.mp4  (before=0)
# [apply] jump_9_m.mp4: counter 0 -> 1 (+1)
#         start=5.28s  dur=5.87s  mute=True  has_audio=True
#
# [progress] [02/5] |#########---------------| label: jump
# [debug] class match: jump  | pool=10
#         - 'jump': candidates=10 min_count=0 max_count=0
#         pool preview: jump_1.mp4:0, jump_10_m.mp4:0, jump_11_m.mp4:0, jump_2_m.mp4:0, jump_3.mp4:0, jump_4.mp4:0, jump_5_m.mp4:0, jump_6.mp4:0, jump_7_m.mp4:0, jump_8_m.mp4:0
# [pick] by class  → jump_3.mp4  (before=0)
# [apply] jump_3.mp4: counter 0 -> 1 (+1)
#         start=1.53s  dur=5.87s  mute=False  has_audio=True
#
# [progress] [03/5] |##############----------| label: fall
# [debug] class match: fall  | pool=1
#         - 'fall': candidates=1 min_count=0 max_count=0
#         pool preview: fall_1.mp4:0
# [pick] by class  → fall_1.mp4  (before=0)
# [apply] fall_1.mp4: counter 0 -> 1 (+1)
#         start=6.54s  dur=5.87s  mute=False  has_audio=True
#
# [progress] [04/5] |###################-----| label: jump
# [debug] class match: jump  | pool=9
#         - 'jump': candidates=9 min_count=0 max_count=0
#         pool preview: jump_1.mp4:0, jump_10_m.mp4:0, jump_11_m.mp4:0, jump_2_m.mp4:0, jump_4.mp4:0, jump_5_m.mp4:0, jump_6.mp4:0, jump_7_m.mp4:0, jump_8_m.mp4:0
# [pick] by class  → jump_8_m.mp4  (before=0)
# [apply] jump_8_m.mp4: counter 0 -> 1 (+1)
#         start=2.00s  dur=5.87s  mute=True  has_audio=True
#
# [progress] [05/5] |########################| label: jump
# [debug] class match: jump  | pool=8
#         - 'jump': candidates=8 min_count=0 max_count=0
#         pool preview: jump_1.mp4:0, jump_10_m.mp4:0, jump_11_m.mp4:0, jump_2_m.mp4:0, jump_4.mp4:0, jump_5_m.mp4:0, jump_6.mp4:0, jump_7_m.mp4:0
# [pick] by class  → jump_6.mp4  (before=0)
# [apply] jump_6.mp4: counter 0 -> 1 (+1)
#         start=0.10s  dur=5.87s  mute=False  has_audio=True
#
# [debug] counter increments this run:
#   +1  fall_1.mp4  (now 1)
#   +1  jump_3.mp4  (now 1)
#   +1  jump_6.mp4  (now 1)
#   +1  jump_8_m.mp4  (now 1)
#   +1  jump_9_m.mp4  (now 1)
#
# [debug] selected order:
#   [01] jump_9_m.mp4
#   [02] jump_3.mp4
#   [03] fall_1.mp4
#   [04] jump_8_m.mp4
#   [05] jump_6.mp4
# [OK] Wrote C:\Users\Thariq\Documents\ITS\PROJECT\PCC\heart_all_visual.mp4  |  durations -> video: 29.333s, audio: 29.325s
# [post] Duration fixed → 29.325s (matches input audio).
# [DEBUG] First few dialogue lines from ASS:
# Dialogue: 0,0:00:00.26,0:00:00.36,Default,,0,0,0,,{\1c&H00FFFF00}Cat{\r} is a
# Dialogue: 0,0:00:00.36,0:00:00.56,Default,,0,0,0,,Cat {\1c&H00FFFF00}is{\r} a
# Dialogue: 0,0:00:00.56,0:00:00.66,Default,,0,0,0,,Cat is {\1c&H00FFFF00}a{\r}
# Dialogue: 0,0:00:00.66,0:00:01.24,Default,,0,0,0,,{\1c&H00FFFF00}perfectionist{\r}\Nwhen it
# Dialogue: 0,0:00:01.24,0:00:01.26,Default,,0,0,0,,perfectionist\Nwhen it
# Dialogue: 0,0:00:01.26,0:00:01.36,Default,,0,0,0,,perfectionist\N{\1c&H00FFFF00}when{\r} it
# Dialogue: 0,0:00:01.36,0:00:01.46,Default,,0,0,0,,perfectionist\Nwhen {\1c&H00FFFF00}it{\r}
# Dialogue: 0,0:00:01.46,0:00:01.64,Default,,0,0,0,,{\1c&H00FFFF00}comes{\r} to\Njumping.
# Dialogue: 0,0:00:01.64,0:00:01.84,Default,,0,0,0,,comes {\1c&H00FFFF00}to{\r}\Njumping.
# Dialogue: 0,0:00:01.84,0:00:02.06,Default,,0,0,0,,comes to\N{\1c&H00FFFF00}jumping.{\r}
# Dialogue: 0,0:00:02.66,0:00:02.78,Default,,0,0,0,,{\1c&H00FFFF00}Before{\r} they\Nleap,
# Dialogue: 0,0:00:02.78,0:00:02.98,Default,,0,0,0,,Before {\1c&H00FFFF00}they{\r}\Nleap,
# Dialogue: 0,0:00:02.98,0:00:03.14,Default,,0,0,0,,Before they\N{\1c&H00FFFF00}leap,{\r}
# Dialogue: 0,0:00:03.50,0:00:03.62,Default,,0,0,0,,{\1c&H00FFFF00}cat{\r} stop
# [OK] Wrote C:\Users\Thariq\Documents\ITS\PROJECT\PCC\heart_all_visual_hardsub.mp4 (font=108px, max_chars_per_line=12)
# [INFO] Inline colour order='rgb', override_len='8'
# [INFO] Temp ASS file saved at: C:\Users\Thariq\AppData\Local\Temp\assfit_e_4ask67\heart_all_fit.ass
# ffmpeg version 8.0-full_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 15.2.0 (Rev8, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-lcms2 --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-libdvdnav --enable-libdvdread --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libopenjpeg --enable-libquirc --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-liboapv --enable-libqrencode --enable-librav1e --enable-libsvtav1 --enable-libvvenc --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-openal --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-liblc3 --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint --enable-whisper
#   libavutil      60.  8.100 / 60.  8.100
#   libavcodec     62. 11.100 / 62. 11.100
#   libavformat    62.  3.100 / 62.  3.100
#   libavdevice    62.  1.100 / 62.  1.100
#   libavfilter    11.  4.100 / 11.  4.100
#   libswscale      9.  1.100 /  9.  1.100
#   libswresample   6.  1.100 /  6.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'C:\Users\Thariq\Documents\ITS\PROJECT\PCC\heart_all_visual.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Duration: 00:00:29.33, start: 0.000000, bitrate: 6907 kb/s
#   Stream #0:0[0x1](und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1080x1920 [SAR 1:1 DAR 9:16], 6732 kb/s, 30 fps, 30 tbr, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc62.11.100 libx264
#   Stream #0:1[0x2](und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 166 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 00000215f960ee00] libass API version: 0x1704000
# [Parsed_subtitles_0 @ 00000215f960ee00] libass source: commit: 0.17.4-15-g534a5f8299c5ab3c2782856fcb843bfea47b7afc
# [Parsed_subtitles_0 @ 00000215f960ee00] Shaper: FriBidi 1.0.16 (SIMPLE) HarfBuzz-ng 11.4.1 (COMPLEX)
# [Parsed_subtitles_0 @ 00000215f960ee00] Using font provider directwrite (with GDI)
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# [Parsed_subtitles_0 @ 00000215f9555340] libass API version: 0x1704000
# [Parsed_subtitles_0 @ 00000215f9555340] libass source: commit: 0.17.4-15-g534a5f8299c5ab3c2782856fcb843bfea47b7afc
# [Parsed_subtitles_0 @ 00000215f9555340] Shaper: FriBidi 1.0.16 (SIMPLE) HarfBuzz-ng 11.4.1 (COMPLEX)
# [Parsed_subtitles_0 @ 00000215f9555340] Using font provider directwrite (with GDI)
# [libx264 @ 00000215f8f8dd00] using SAR=1/1
# [libx264 @ 00000215f8f8dd00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 00000215f8f8dd00] profile High, level 4.0, 4:2:0, 8-bit
# [libx264 @ 00000215f8f8dd00] 264 - core 165 r3222 b35605a - H.264/MPEG-4 AVC codec - Copyleft 2003-2025 - http://www.videolan.org/x264.html - options: cabac=1 ref=1 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=2 psy=1 psy_rd=1.00:0.00 mixed_ref=0 me_range=16 chroma_me=1 trellis=0 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=0 threads=30 lookahead_threads=10 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=1 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=10 rc=crf mbtree=1 crf=18.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'C:\Users\Thariq\Documents\ITS\PROJECT\PCC\heart_all_visual_hardsub.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf62.3.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(tv, bt709, progressive), 1080x1920 [SAR 1:1 DAR 9:16], q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       encoder         : Lavc62.11.100 libx264
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
#   Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, mono, fltp, 166 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       vendor_id       : [0][0][0][0]
# [Parsed_subtitles_0 @ 00000215f9555340] fontselect: (Arial, 400, 0) -> ArialMT, 0, ArialMT
# frame=  119 fps=0.0 q=24.0 size=    1536KiB time=00:00:03.90 bitrate=3226.5kbits/s speed=7.66x elapsed=0:00:00.50
# frame=  237 fps=232 q=24.0 size=    4096KiB time=00:00:07.83 bitrate=4283.6kbits/s speed=7.66x elapsed=0:00:01.02
# frame=  337 fps=219 q=24.0 size=    7680KiB time=00:00:11.16 bitrate=5634.2kbits/s speed=7.26x elapsed=0:00:01.53
# frame=  448 fps=218 q=21.0 size=   11520KiB time=00:00:14.86 bitrate=6347.9kbits/s speed=7.22x elapsed=0:00:02.05
# frame=  561 fps=218 q=24.0 size=   15104KiB time=00:00:18.63 bitrate=6640.4kbits/s speed=7.26x elapsed=0:00:02.56
# frame=  677 fps=219 q=21.0 size=   18688KiB time=00:00:22.50 bitrate=6804.1kbits/s speed=7.27x elapsed=0:00:03.09
# frame=  771 fps=214 q=24.0 size=   21504KiB time=00:00:25.63 bitrate=6872.3kbits/s speed= 7.1x elapsed=0:00:03.60
# [mp4 @ 00000215f901e900] Starting second pass: moving the moov atom to the beginning of the file
# [out#0/mp4 @ 00000215f8f88f40] video:24355KiB audio:596KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.125979%
# frame=  880 fps=221 q=-1.0 Lsize=   24982KiB time=00:00:29.26 bitrate=6992.7kbits/s speed=7.33x elapsed=0:00:03.99
# [libx264 @ 00000215f8f8dd00] frame I:15    Avg QP:15.03  size: 98539
# [libx264 @ 00000215f8f8dd00] frame P:466   Avg QP:17.85  size: 40784
# [libx264 @ 00000215f8f8dd00] frame B:399   Avg QP:20.18  size: 11166
# [libx264 @ 00000215f8f8dd00] consecutive B-frames: 25.0% 41.4%  6.8% 26.8%
# [libx264 @ 00000215f8f8dd00] mb I  I16..4: 18.7% 45.9% 35.4%
# [libx264 @ 00000215f8f8dd00] mb P  I16..4: 13.5% 31.8%  3.4%  P16..4: 19.0% 10.1%  5.8%  0.0%  0.0%    skip:16.5%
# [libx264 @ 00000215f8f8dd00] mb B  I16..4:  2.3%  4.7%  0.2%  B16..8: 16.9%  6.1%  0.9%  direct: 6.2%  skip:62.7%  L0:38.0% L1:47.0% BI:15.0%
# [libx264 @ 00000215f8f8dd00] 8x8 transform intra:64.2% inter:34.9%
# [libx264 @ 00000215f8f8dd00] coded y,uvDC,uvAC intra: 45.4% 44.8% 8.9% inter: 9.4% 12.7% 0.4%
# [libx264 @ 00000215f8f8dd00] i16 v,h,dc,p: 54% 27% 10% 10%
# [libx264 @ 00000215f8f8dd00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 30% 15%  5%  5%  5%  5%  5%  5%
# [libx264 @ 00000215f8f8dd00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 23% 10%  6%  7%  7%  7%  7%  5%
# [libx264 @ 00000215f8f8dd00] i8c dc,h,v,p: 54% 22% 19%  5%
# [libx264 @ 00000215f8f8dd00] Weighted P-Frames: Y:6.0% UV:0.6%
# [libx264 @ 00000215f8f8dd00] kb/s:6801.42

# %%
# .\.venv\Scripts\Activate.ps1

# %%
# python .\kokoro_heart.py 

# stable-ts heart_all.wav --output heart_all.srt --output_format srt --device cuda --language en --word_timestamps True --max_chars 42 --max_words 4

# (Get-Content .\heart_all.srt) -replace '#00ff00','#ff00ffff' |  Set-Content .\heart_all.srt -Encoding utf8
 
#  python footage.py --footage_dir footage --input_txt input.txt --subs_srt heart_all.srt --audio_wav heart_all.wav --out_video heart_all_visual.mp4 --debug

# python burn_hardsub_fit_ass.py --keep_font_color --ass_color_order rgb  --margin_v_ratio 0.24  --base_scale 0.056

# %%
# !Remove-Item -Force .\footage\.selection_counters.json
# Out:
# 'Remove-Item' is not recognized as an internal or external command,
# operable program or batch file.
